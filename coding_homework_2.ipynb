# %% [markdown]
# <a href="https://colab.research.google.com/github/oliviahfrank/hello/blob/main/coding_homework_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Olivia Frank
# *Intro to neural data analysis*
# **February 20th, 2026**

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
# This cell is just form importing all of the functions we will use throughout the rest of the notebook

# %%
url='https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_pvalb.csv'
url2='https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_sst.csv'

v_rest2=np.loadtxt(url)
v_rest1=np.loadtxt(url2)
#This step imports each of the urls to make the data set accessable by numpy
# v_rest1 is sst and v_rest2 is pvalb

# %%
v_rest=[v_rest1,v_rest2]
# Here I am combining the two data sets to create the 2 by 500

print(np.shape(v_rest))
# Now I will print the shape of the combined data set
# Out:
# (2, 500)

# %%
np.size(v_rest)
# The size is the area or the rows mulitplied by the columns
# Out:
# 1000

# %%
v_rest[0]
#this is the first row of the combined data set. That gives 500 values all in row 1
# Out:
# array([-68.24292501, -69.60158234, -76.03420105, -71.16118393,
#        -76.35402679, -70.89105013, -64.11880341, -72.8632112 ,
#        -78.96890068, -55.4531032 , -60.98506045, -66.61118807,
#        -67.08294233, -73.90523593, -74.63317594, -49.27067811,
#        -76.05053997, -65.45417595, -58.53314018, -66.28985665,
#        -64.09106996, -71.49303228, -65.11718958, -73.74140637,
#        -74.81462097, -71.32343356, -74.46990373, -65.03939126,
#        -71.94757271, -73.42034054, -71.10602856, -61.28795481,
#        -73.79654069, -64.48533249, -69.65824959, -73.71225967,
#        -85.56860669, -57.49219704, -76.91730436, -62.61127641,
#        -67.08071963, -78.45983535, -78.87342682, -76.14055703,
#        -62.40101166, -72.41336346, -62.03701146, -63.30990855,
#        -62.02654052, -73.0206111 , -63.11713295, -70.05060087,
#        -75.7537974 , -57.15310111, -72.52368011, -70.86691952,
#        -65.435009  , -66.87690226, -70.79107895, -71.34088898,
# ...

# %%
v_rest = np.array(v_rest)
v_rest[:, 2].sum()
#here I am converting v_rest into a numpy array, I am not sure why it was not before
# Then I am finding the sum of the third column which is column number 2
# Out:
# np.float64(-151.75359464)

# %%
v_rest[1,-2]
#I am pulling out the second to last value in the array with negative indexing.
# I can use the -2 for the second to last value because there is no -0.
# Out:
# np.float64(-49.80412917)

# %%
plt.hist(v_rest[0])

plt.ylabel('Marker')
plt.xlabel('Resting Membrane Potential')
#I added lables to the histogram of v_rest and made the histogram of the first row of v_rest
# Out:
# Text(0.5, 0, 'Resting Membrane Potential')

# %%
v_rest_mean_sst = st.mean(v_rest1)
v_rest_mean_pvalb = st.mean(v_rest2)
print(v_rest_mean_sst)
print(v_rest_mean_pvalb)
#I am finding the mean of each sst and pvalb
# Out:
# -67.73465864056
# -69.97869017908

# %% [markdown]
# The rows each have the same amount of columns and rows individually, however the pvalb neurons have a more negative mean resting membrane potential.

# %%
import scipy.stats as stats
# I am importing this so that I can run a t-test and determine if the difference in means is meaningful

# %%
stats.ttest_ind(v_rest[0],v_rest[1])
# testing the statistics between pvalb and sst
# Out:
# TtestResult(statistic=np.float64(5.837507010328816), pvalue=np.float64(7.159828660199036e-09), df=np.float64(998.0))

# %% [markdown]
# ### T-Test Results
#
# the p value was much less than 0.05 at 7.16*10^-9. That means the difference in the resting membrane potential is significant.
