# %% [markdown]
# <a href="https://colab.research.google.com/github/oliviahfrank/hello/blob/main/coding_homework_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import matplotlib

from matplotlib import pyplot as plt

import pandas as pd

import numpy as np

# %% [markdown]
# ###Olivia Frank
# *Intro to Neural Data Analysis*
#
# **February 13**

# %%
url ='https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_pvalb.csv'
pandas_data1=pd.read_csv(url)

url2='https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_sst.csv'
pandas_data2=pd.read_csv(url2)

# %%
data1 = pandas_data1.values.tolist()
data2 = pandas_data2.values.tolist()

# %%
data1 = np.squeeze(data1)
data2 = np.squeeze(data2)

# %%
print(data1)
# Out:
# [-49.92227745 -75.71939359 -72.36807022 -63.09300825 -75.5469301
#  -66.51929994 -71.50055833 -69.19734478 -76.38503876 -65.96166784
#  -65.47980734 -59.95571342 -69.94688056 -74.56247482 -69.56489473
#  -66.74425422 -71.57112946 -71.23040619 -71.99371229 -79.66145376
#  -60.18065071 -70.27087275 -69.51328714 -76.44443893 -61.01587601
#  -66.54598575 -68.57077581 -72.52978809 -69.55428314 -79.4150077
#  -66.12706146 -69.61513367 -69.59012375 -78.5484375  -69.97646046
#  -63.67217359 -69.80182966 -72.46670193 -72.17225588 -63.49881536
#  -67.87744827 -75.48496437 -73.37054698 -73.57516549 -68.23623112
#  -64.82718235 -61.53974394 -64.49179316 -73.83959484 -65.12582397
#  -76.59335175 -71.79500173 -68.45139211 -70.45548483 -78.36537799
#  -73.34691535 -65.32437515 -79.56857345 -73.24215508 -69.29635385
#  -69.78741977 -75.46377702 -62.96309948 -71.2908991  -66.48377482
#  -70.91091711 -73.812372   -72.20985667 -69.96945784 -73.89710903
# ...

# %%
print(data2[[2,3,4]])
#used double brackets to indicate list of indices rather than dimentions
# Out:
# [-71.16118393 -76.35402679 -70.89105013]

# %%
print(data1[[-1,-2]])
# Out:
# [-54.08427915 -49.80412917]

# %%
print(data2.dtype)
# Out:
# float64

# %%
v_rest_pvalb = plt.hist(pandas_data1)

# %%
v_rest_pvalb = plt.hist(pandas_data1)

plt.xlabel('resting potential (mV)')
plt.ylabel('pvalb')
# Out:
# Text(0, 0.5, 'pvalb')

# %%
v_rest_sst = plt.hist(pandas_data2)

plt.xlabel('resting potential (mV)')
plt.ylabel('sst')
# Out:
# Text(0, 0.5, 'sst')

# %% [markdown]
# They are both slightly negativly skewed, however the sst histogram has slightly higher peak values than the pvalb histogram. The sst histogram also has slightly lower high values and a wider spread of resting potential values than the pvalb histogram.

# %%
data3 = [data1, data2]

# %%
print(data3[1][-1])
# Out:
# -75.10678711
